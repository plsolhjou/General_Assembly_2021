# %% [markdown]
# # Relationship between COVID-19 Mortality Rates & Obesity

# %% [markdown]
# Introduction:
#
# In this notebook, I used data from food intake by countries along with mortality data associated with COVID-19.
#
# Data for this project is taken from Kaggle dataset. Written by the owner of the dataset:
#
# "In this dataset, I have combined data of different types of food, world population obesity and undernourished rate, and global COVID-19 cases count from around the world in order to learn more about how a healthy eating style could help combat COVID-19. And from the dataset, we can gather information regarding diet patterns from countries with lower COVID infection rate, and adjust our own diet accordingly."
#
#
# Five Files in the Kaggle dataset:
#
# -Fat_Supply_Quantity_Data.csv: percentage of fat intake from different food groups for 170 different countries.
#
# -Food_Supply_Quantity_kg_Data.csv: percentage of food intake( in  𝑘𝑔  ) from different food groups for 170 different countries.
#
# -Food_Supply_kcal_Data.csv: percentage of energy intake (in  𝑘𝑐𝑎𝑙 ) from different food groups for 170 different countries.
#
# -Protein_Supply_Quantity_Data.csv: percentage of protein intake from different food groups for 170 different countries.
#
# -Supply_Food_Data_Descriptions.csv: This dataset is obtained from FAO.org, and is used to show the specific types of food that belongs to each category for the above datasets.
#
# All of these files have obesity, undernourishment and COVID-19 cases columns as percentages of the total population.

# %%
#import packages 
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_palette("Set2")
np.random.seed(42) #make notebook's output stable each run

# %%
#read in the files
fat_supply_quantity = pd.read_csv('/Users/perrisolhjou/Downloads/Fat_Supply_Quantity_Data (2).csv') 
food_kcal = pd.read_csv('/Users/perrisolhjou/Downloads/Food_Supply_kcal_Data (1).csv')
food_kg = pd.read_csv('/Users/perrisolhjou/Downloads/Food_Supply_Quantity_kg_Data.csv')
protein_quantity = pd.read_csv('/Users/perrisolhjou/Downloads/Protein_Supply_Quantity_Data (1).csv') 
supply_food = pd.read_csv('/Users/perrisolhjou/Downloads/Supply_Food_Data_Descriptions (2).csv')

# %%
# Define features and labels
feature_names = ['animal_products', 'cereals_excluding_beer', 'obesity', 'vegetal_products']
label_name = 'deaths'

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
#showing the first five rows and columns of the dataset
fat_supply_quantity.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan                  0.0          21.6397       6.2224
# 1              Albania                  0.0          32.0002       3.4172
# 2              Algeria                  0.0          14.4175       0.8972
# 3               Angola                  0.0          15.3041       1.3130
# 4  Antigua and Barbuda                  0.0          27.7033       4.6686
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                    8.0353  0.6859         0.0327
# 1                      0.0                    2.6734  1.6448         0.1445
# 2                      0.0                    4.2035  1.2171         0.2008
# 3                      0.0                    6.5545  0.1539         1.4155
# 4                      0.0                    3.2153  0.3872         1.5263
#
#    Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  Obesity  \
# 0                   0.4246   6.1244  ...         17.0831      0.3593      4.5
# 1                   0.6418   8.7428  ...          9.2443      0.6503     22.3
# 2                   0.5772   3.8961  ...         27.3606      0.5145     26.6
# 3                   0.3488  11.0268  ...         22.4638      0.1231      6.8
# 4                   1.2177  14.3202  ...         14.4436      0.2469     19.1
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.142134  0.006186   0.123374  0.012574  38928000.0
# 1             6.2   2.967301  0.050951   1.792636  1.123714   2838000.0
# 2             3.9   0.244897  0.006558   0.167572  0.070767  44357000.0
# 3              25   0.061687  0.001461   0.056808  0.003419  32522000.0
# 4             NaN   0.293878  0.007143   0.190816  0.095918     98000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 4                             %
#
# [5 rows x 32 columns]

# %%
food_kcal.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           4.7774       0.8504
# 1              Albania               0.9120          16.0930       1.0591
# 2              Algeria               0.0896           6.0326       0.1941
# 3               Angola               1.9388           4.6927       0.2644
# 4  Antigua and Barbuda               2.3041          15.3672       1.5429
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   37.1186  0.1501         0.0000
# 1                      0.0                   16.2107  0.8091         0.1471
# 2                      0.0                   25.0112  0.4181         0.1195
# 3                      0.0                   18.3521  0.0441         0.8372
# 4                      0.0                   13.7215  0.2057         1.7280
#
#    Fruits - Excluding Wine    Meat  ...  Vegetable Oils  Vegetables  Obesity  \
# 0                   1.4757  1.2006  ...          2.3012      0.7504      4.5
# 1                   3.8982  3.8688  ...          2.8244      2.7508     22.3
# 2                   3.1805  1.2543  ...          5.7638      2.0457     26.6
# 3                   2.3133  2.9302  ...          4.2741      0.3525      6.8
# 4                   3.6824  7.0356  ...          4.6904      1.2960     19.1
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.142134  0.006186   0.123374  0.012574  38928000.0
# 1             6.2   2.967301  0.050951   1.792636  1.123714   2838000.0
# 2             3.9   0.244897  0.006558   0.167572  0.070767  44357000.0
# 3              25   0.061687  0.001461   0.056808  0.003419  32522000.0
# 4             NaN   0.293878  0.007143   0.190816  0.095918     98000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 4                             %
#
# [5 rows x 32 columns]

# %%
food_kg.head()
# Out:
#                Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 0          Afghanistan               0.0014       0.1973           9.4341
# 1              Albania               1.6719       0.1357          18.7684
# 2              Algeria               0.2711       0.0282           9.6334
# 3               Angola               5.8087       0.0560           4.9278
# 4  Antigua and Barbuda               3.5764       0.0087          16.6613
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   24.8097  0.2099         0.0350
# 1                      0.0                    5.7817  0.5815         0.2126
# 2                      0.0                   13.6816  0.5277         0.2416
# 3                      0.0                    9.1085  0.0587         1.7707
# 4                      0.0                    5.9960  0.2274         4.1489
#
#    Fruits - Excluding Wine    Meat  ...  Vegetables  Vegetal Products  \
# 0                   5.3495  1.2020  ...      6.7642           40.5645
# 1                   6.7861  1.8845  ...     11.7753           31.2304
# 2                   6.3801  1.1305  ...     11.6484           40.3651
# 3                   6.0005  2.0571  ...      2.3041           45.0722
# 4                  10.7451  5.6888  ...      5.4495           33.3233
#
#    Obesity  Undernourished  Confirmed    Deaths  Recovered    Active  \
# 0      4.5            29.8   0.138283  0.005970   0.116713  0.015601
# 1     22.3             6.2   2.347956  0.044574   1.396230  0.907153
# 2     26.6             3.9   0.233066  0.006373   0.158234  0.068458
# 3      6.8              25   0.057435  0.001316   0.049566  0.006552
# 4     19.1             NaN   0.187755  0.006122   0.159184  0.022449
#
#    Population  Unit (all except Population)
# 0  38928000.0                             %
# 1   2838000.0                             %
# 2  44357000.0                             %
# 3  32522000.0                             %
# 4     98000.0                             %
#
# [5 rows x 32 columns]

# %%
protein_quantity.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
#    Fruits - Excluding Wine     Meat  ...  Vegetables  Miscellaneous  Obesity  \
# 0                   0.5824   3.1337  ...      1.1370         0.0462      4.5
# 1                   1.2757   7.6582  ...      3.2456         0.0544     22.3
# 2                   1.1624   3.5088  ...      3.1267         0.1399     26.6
# 3                   1.2754   7.6248  ...      0.8133         0.0924      6.8
# 4                   1.2586  16.0670  ...      1.6024         0.2947     19.1
#
#    Undernourished  Confirmed    Deaths  Recovered    Active  Population  \
# 0            29.8   0.142134  0.006186   0.123374  0.012574  38928000.0
# 1             6.2   2.967301  0.050951   1.792636  1.123714   2838000.0
# 2             3.9   0.244897  0.006558   0.167572  0.070767  44357000.0
# 3              25   0.061687  0.001461   0.056808  0.003419  32522000.0
# 4             NaN   0.293878  0.007143   0.190816  0.095918     98000.0
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 4                             %
#
# [5 rows x 32 columns]

# %%
supply_food.head()
# Out:
#                  Categories                                              Items
# 0       Alcoholic Beverages  Alcohol, Non-Food; Beer; Beverages, Alcoholic;...
# 1               Animal fats  Butter, Ghee; Cream; Fats, Animals, Raw; Fish,...
# 2           Animal Products  Aquatic Animals, Others; Aquatic Plants; Bovin...
# 3   Aquatic Products, Other  Aquatic Animals, Others; Aquatic Plants; Meat,...
# 4  Cereals - Excluding Beer  Barley and products; Cereals, Other; Maize and...

# %%
fat_supply_quantity.columns
# Out:
# Index(['Country', 'Alcoholic Beverages', 'Animal Products', 'Animal fats',
#        'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs',
#        'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Miscellaneous',
#        'Milk - Excluding Butter', 'Offals', 'Oilcrops', 'Pulses', 'Spices',
#        'Starchy Roots', 'Stimulants', 'Sugar Crops', 'Sugar & Sweeteners',
#        'Treenuts', 'Vegetal Products', 'Vegetable Oils', 'Vegetables',
#        'Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered',
#        'Active', 'Population', 'Unit (all except Population)'],
#       dtype='object')

# %%
fat_supply_quantity.isnull().sum()
#check for missing values in sample (handle null values)
# Out:
# Country                         0
# Alcoholic Beverages             0
# Animal Products                 0
# Animal fats                     0
# Aquatic Products, Other         0
# Cereals - Excluding Beer        0
# Eggs                            0
# Fish, Seafood                   0
# Fruits - Excluding Wine         0
# Meat                            0
# Miscellaneous                   0
# Milk - Excluding Butter         0
# Offals                          0
# Oilcrops                        0
# Pulses                          0
# Spices                          0
# Starchy Roots                   0
# Stimulants                      0
# Sugar Crops                     0
# Sugar & Sweeteners              0
# Treenuts                        0
# Vegetal Products                0
# Vegetable Oils                  0
# Vegetables                      0
# Obesity                         3
# Undernourished                  7
# Confirmed                       6
# Deaths                          6
# Recovered                       6
# Active                          8
# Population                      0
# Unit (all except Population)    0
# dtype: int64

# %%
fat_supply_quantity.dropna(inplace=True)
fat_supply_quantity.isnull().sum()
#Identifying null values and dropping the null values
# Out:
# Country                         0
# Alcoholic Beverages             0
# Animal Products                 0
# Animal fats                     0
# Aquatic Products, Other         0
# Cereals - Excluding Beer        0
# Eggs                            0
# Fish, Seafood                   0
# Fruits - Excluding Wine         0
# Meat                            0
# Miscellaneous                   0
# Milk - Excluding Butter         0
# Offals                          0
# Oilcrops                        0
# Pulses                          0
# Spices                          0
# Starchy Roots                   0
# Stimulants                      0
# Sugar Crops                     0
# Sugar & Sweeteners              0
# Treenuts                        0
# Vegetal Products                0
# Vegetable Oils                  0
# Vegetables                      0
# Obesity                         0
# Undernourished                  0
# Confirmed                       0
# Deaths                          0
# Recovered                       0
# Active                          0
# Population                      0
# Unit (all except Population)    0
# dtype: int64

# %%
fat_supply_quantity["Undernourished"]
# Out:
# 0      29.8
# 1       6.2
# 2       3.9
# 3        25
# 5       4.6
#        ...
# 165    21.2
# 166     9.3
# 167    38.9
# 168    46.7
# 169    51.3
# Name: Undernourished, Length: 154, dtype: object

# %%
fat_supply_quantity.shape
#Identifying that we have data only from 154 countries (not the entire selection) (handle sampling )
# Out:
# (154, 32)

# %%
#change the indices of the dataframe to match the new parameters of 154 countries
fat_supply_quantity.set_index("Country", inplace=True)

# %%
fat_supply_quantity["Undernourished"] = fat_supply_quantity["Undernourished"].replace('<2.5','2.5').astype(float)
fat_supply_quantity.describe()
# Out:
#        Alcoholic Beverages  Animal Products  Animal fats  \
# count           154.000000       154.000000   154.000000
# mean              0.001142        20.371363     4.156129
# std               0.010051         8.027724     3.360236
# min               0.000000         5.018200     0.167800
# 25%               0.000000        14.531900     1.624975
# 50%               0.000000        20.099700     3.304450
# 75%               0.000000        26.707425     6.253750
# max               0.097600        36.901800    14.937300
#
#        Aquatic Products, Other  Cereals - Excluding Beer        Eggs  \
# count               154.000000                154.000000  154.000000
# mean                  0.000497                  4.470623    0.947074
# std                   0.004242                  3.248573    0.661384
# min                   0.000000                  0.990800    0.058000
# 25%                   0.000000                  2.010925    0.363475
# 50%                   0.000000                  3.454750    0.867750
# 75%                   0.000000                  5.694575    1.251575
# max                   0.051100                 18.376300    3.275600
#
#        Fish, Seafood  Fruits - Excluding Wine        Meat  Miscellaneous  ...  \
# count     154.000000               154.000000  154.000000     154.000000  ...
# mean        0.825396                 0.536843    9.075049       0.050782  ...
# std         0.930353                 0.856490    4.456419       0.065645  ...
# min         0.031500                 0.037300    0.906100       0.000000  ...
# 25%         0.320300                 0.235125    6.029075       0.009425  ...
# 50%         0.567000                 0.366000    8.964900       0.028000  ...
# 75%         1.021775                 0.577800   11.396200       0.067675  ...
# max         8.406800                 9.672700   26.429200       0.456100  ...
#
#        Vegetal Products  Vegetable Oils  Vegetables     Obesity  \
# count        154.000000      154.000000  154.000000  154.000000
# mean          29.628879       18.825103    0.306868   18.449351
# std            8.027314        6.824286    0.205127    9.519483
# min           13.098200        4.954900    0.026300    2.100000
# 25%           23.293600       14.029650    0.175725    8.250000
# 50%           29.902150       18.363000    0.247050   21.300000
# 75%           35.471300       23.697575    0.362925   25.700000
# max           44.981800       36.418600    1.153800   45.500000
#
#        Undernourished   Confirmed      Deaths   Recovered      Active  \
# count      154.000000  154.000000  154.000000  154.000000  154.000000
# mean        11.324026    2.060157    0.039882    1.464742    0.555533
# std         11.771718    2.396535    0.049285    1.950855    1.359852
# min          2.500000    0.000312    0.000000    0.000000    0.000000
# 25%          2.500000    0.141688    0.002086    0.095044    0.012857
# 50%          7.050000    1.035083    0.012576    0.476994    0.081040
# 75%         15.075000    3.534770    0.069680    2.643213    0.369904
# max         59.600000   10.408199    0.185428    9.039871    8.019819
#
#          Population
# count  1.540000e+02
# mean   4.796579e+07
# std    1.639258e+08
# min    7.200000e+04
# 25%    3.403500e+06
# 50%    1.058950e+07
# 75%    3.383650e+07
# max    1.402385e+09
#
# [8 rows x 30 columns]

# %%
#Identifying that this column is not at all needed
fat_supply_quantity.drop('Unit (all except Population)',axis =1, inplace=True)
fat_supply_quantity.describe()
# Out:
#        Alcoholic Beverages  Animal Products  Animal fats  \
# count           154.000000       154.000000   154.000000
# mean              0.001142        20.371363     4.156129
# std               0.010051         8.027724     3.360236
# min               0.000000         5.018200     0.167800
# 25%               0.000000        14.531900     1.624975
# 50%               0.000000        20.099700     3.304450
# 75%               0.000000        26.707425     6.253750
# max               0.097600        36.901800    14.937300
#
#        Aquatic Products, Other  Cereals - Excluding Beer        Eggs  \
# count               154.000000                154.000000  154.000000
# mean                  0.000497                  4.470623    0.947074
# std                   0.004242                  3.248573    0.661384
# min                   0.000000                  0.990800    0.058000
# 25%                   0.000000                  2.010925    0.363475
# 50%                   0.000000                  3.454750    0.867750
# 75%                   0.000000                  5.694575    1.251575
# max                   0.051100                 18.376300    3.275600
#
#        Fish, Seafood  Fruits - Excluding Wine        Meat  Miscellaneous  ...  \
# count     154.000000               154.000000  154.000000     154.000000  ...
# mean        0.825396                 0.536843    9.075049       0.050782  ...
# std         0.930353                 0.856490    4.456419       0.065645  ...
# min         0.031500                 0.037300    0.906100       0.000000  ...
# 25%         0.320300                 0.235125    6.029075       0.009425  ...
# 50%         0.567000                 0.366000    8.964900       0.028000  ...
# 75%         1.021775                 0.577800   11.396200       0.067675  ...
# max         8.406800                 9.672700   26.429200       0.456100  ...
#
#        Vegetal Products  Vegetable Oils  Vegetables     Obesity  \
# count        154.000000      154.000000  154.000000  154.000000
# mean          29.628879       18.825103    0.306868   18.449351
# std            8.027314        6.824286    0.205127    9.519483
# min           13.098200        4.954900    0.026300    2.100000
# 25%           23.293600       14.029650    0.175725    8.250000
# 50%           29.902150       18.363000    0.247050   21.300000
# 75%           35.471300       23.697575    0.362925   25.700000
# max           44.981800       36.418600    1.153800   45.500000
#
#        Undernourished   Confirmed      Deaths   Recovered      Active  \
# count      154.000000  154.000000  154.000000  154.000000  154.000000
# mean        11.324026    2.060157    0.039882    1.464742    0.555533
# std         11.771718    2.396535    0.049285    1.950855    1.359852
# min          2.500000    0.000312    0.000000    0.000000    0.000000
# 25%          2.500000    0.141688    0.002086    0.095044    0.012857
# 50%          7.050000    1.035083    0.012576    0.476994    0.081040
# 75%         15.075000    3.534770    0.069680    2.643213    0.369904
# max         59.600000   10.408199    0.185428    9.039871    8.019819
#
#          Population
# count  1.540000e+02
# mean   4.796579e+07
# std    1.639258e+08
# min    7.200000e+04
# 25%    3.403500e+06
# 50%    1.058950e+07
# 75%    3.383650e+07
# max    1.402385e+09
#
# [8 rows x 30 columns]

# %%
cor = fat_supply_quantity.corr()
#Analyzing correlation matrix to see dietary factors affecting confirmed cases

# %% [markdown]
# # Data Visualizations

# %%
plt.figure(figsize=(20,20))
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
#visual heatmap to see correlation in dataframe
#assumption: obestity and unhealthy foods = higher mortality rates of COVID-19

# %%
cor_target = abs(cor["Confirmed"]).drop(["Confirmed","Deaths","Recovered","Active",]).sort_values(ascending=False)
#Analyzing highly correlated features with confirmed cases
relevant_features = cor_target[cor_target>0.4]
relevant_features
# Out:
# Obesity                     0.525496
# Animal fats                 0.511528
# Vegetal Products            0.498624
# Animal Products             0.498583
# Stimulants                  0.483254
# Undernourished              0.458968
# Cereals - Excluding Beer    0.439677
# Milk - Excluding Butter     0.411789
# Name: Confirmed, dtype: float64

# %%
fat_supply_quantity["Population"].max()
# Out:
# 1402385000.0

# %%
#Let's look at obesity 
#assumption: obesity leads to death by covid-19
fat_supply_quantity = fat_supply_quantity.sort_values(by="Obesity",ascending=False)
fat_supply_quantity.head()
# Out:
#                           Alcoholic Beverages  Animal Products  Animal fats  \
# Country
# Samoa                                     0.0          21.6806       4.7780
# United States of America                  0.0          21.2045       3.3013
# Kuwait                                    0.0          19.8923       2.1588
# Saudi Arabia                              0.0          15.3954       2.6475
# Jordan                                    0.0          12.2622       1.8696
#
#                           Aquatic Products, Other  Cereals - Excluding Beer  \
# Country
# Samoa                                      0.0036                    1.5771
# United States of America                   0.0000                    1.2829
# Kuwait                                     0.0000                    3.0847
# Saudi Arabia                               0.0000                    5.2126
# Jordan                                     0.0000                    3.7391
#
#                             Eggs  Fish, Seafood  Fruits - Excluding Wine  \
# Country
# Samoa                     0.2227         1.8968                   0.6287
# United States of America  1.2500         0.3887                   0.4426
# Kuwait                    2.3242         0.3732                   0.3496
# Saudi Arabia              0.9019         0.4122                   0.4219
# Jordan                    0.5224         0.3189                   0.1980
#
#                              Meat  Miscellaneous  ...  Vegetal Products  \
# Country                                           ...
# Samoa                     13.2418         0.0683  ...           28.3194
# United States of America   9.4166         0.0000  ...           28.7970
# Kuwait                     9.5706         0.1086  ...           30.1101
# Saudi Arabia               6.9243         0.0873  ...           34.6070
# Jordan                     5.8122         0.0385  ...           37.7378
#
#                           Vegetable Oils  Vegetables  Obesity  Undernourished  \
# Country
# Samoa                             8.3345      0.0431     45.5             2.7
# United States of America         23.6117      0.1944     37.3             2.5
# Kuwait                           21.2150      0.5055     37.0             2.8
# Saudi Arabia                     25.4182      0.1891     35.0             7.1
# Jordan                           29.0553      0.2694     33.4            12.2
#
#                           Confirmed    Deaths  Recovered    Active  \
# Country
# Samoa                      0.001000  0.000000   0.001000  0.000000
# United States of America   8.159922  0.140103   0.000000  8.019819
# Kuwait                     3.624728  0.020550   3.434087  0.170092
# Saudi Arabia               1.055795  0.018256   1.030898  0.006641
# Jordan                     3.126276  0.040912   2.991760  0.093604
#
#                            Population
# Country
# Samoa                        200000.0
# United States of America  329878000.0
# Kuwait                      4691000.0
# Saudi Arabia               35041000.0
# Jordan                     10679000.0
#
# [5 rows x 30 columns]

# %%
cor_target = abs(cor["Confirmed"]).drop(["Confirmed","Deaths","Recovered","Active",]).sort_values(ascending=False)
#Selecting highly correlated features within the correlation matrix
relevant_features = cor_target[cor_target>0.4]
relevant_features
#obesity is highly correlated
# Out:
# Obesity                     0.525496
# Animal fats                 0.511528
# Vegetal Products            0.498624
# Animal Products             0.498583
# Stimulants                  0.483254
# Undernourished              0.458968
# Cereals - Excluding Beer    0.439677
# Milk - Excluding Butter     0.411789
# Name: Confirmed, dtype: float64

# %%
fat_supply_quantity["Population"].max()
# Out:
# 1402385000.0

# %%
#lets look at obesity within the fat supply file
df_Obesity = fat_supply_quantity.sort_values(by ="Obesity",ascending=False)
df_Obesity.head()
# Out:
#                           Alcoholic Beverages  Animal Products  Animal fats  \
# Country
# Samoa                                     0.0          21.6806       4.7780
# United States of America                  0.0          21.2045       3.3013
# Kuwait                                    0.0          19.8923       2.1588
# Saudi Arabia                              0.0          15.3954       2.6475
# Jordan                                    0.0          12.2622       1.8696
#
#                           Aquatic Products, Other  Cereals - Excluding Beer  \
# Country
# Samoa                                      0.0036                    1.5771
# United States of America                   0.0000                    1.2829
# Kuwait                                     0.0000                    3.0847
# Saudi Arabia                               0.0000                    5.2126
# Jordan                                     0.0000                    3.7391
#
#                             Eggs  Fish, Seafood  Fruits - Excluding Wine  \
# Country
# Samoa                     0.2227         1.8968                   0.6287
# United States of America  1.2500         0.3887                   0.4426
# Kuwait                    2.3242         0.3732                   0.3496
# Saudi Arabia              0.9019         0.4122                   0.4219
# Jordan                    0.5224         0.3189                   0.1980
#
#                              Meat  Miscellaneous  ...  Vegetal Products  \
# Country                                           ...
# Samoa                     13.2418         0.0683  ...           28.3194
# United States of America   9.4166         0.0000  ...           28.7970
# Kuwait                     9.5706         0.1086  ...           30.1101
# Saudi Arabia               6.9243         0.0873  ...           34.6070
# Jordan                     5.8122         0.0385  ...           37.7378
#
#                           Vegetable Oils  Vegetables  Obesity  Undernourished  \
# Country
# Samoa                             8.3345      0.0431     45.5             2.7
# United States of America         23.6117      0.1944     37.3             2.5
# Kuwait                           21.2150      0.5055     37.0             2.8
# Saudi Arabia                     25.4182      0.1891     35.0             7.1
# Jordan                           29.0553      0.2694     33.4            12.2
#
#                           Confirmed    Deaths  Recovered    Active  \
# Country
# Samoa                      0.001000  0.000000   0.001000  0.000000
# United States of America   8.159922  0.140103   0.000000  8.019819
# Kuwait                     3.624728  0.020550   3.434087  0.170092
# Saudi Arabia               1.055795  0.018256   1.030898  0.006641
# Jordan                     3.126276  0.040912   2.991760  0.093604
#
#                            Population
# Country
# Samoa                        200000.0
# United States of America  329878000.0
# Kuwait                      4691000.0
# Saudi Arabia               35041000.0
# Jordan                     10679000.0
#
# [5 rows x 30 columns]

# %%
plt.figure(figsize=(40, 7))
plt.subplot(1,2,1)

plt.plot(df_Obesity["Obesity"],df_Obesity["Confirmed"], label="Confirmed")
plt.plot(df_Obesity["Obesity"],df_Obesity["Recovered"], label="Recovered")

plt.title('Obesity Vs Confirmed cases')
plt.xlabel('Percentage of Obesity')
plt.ylabel('Confirmed cases')
plt.legend(loc='best')

# %%
#Spike in Obesity confirmed cases as the percentage of obestiy rises

# %%
#A look into overall eating of food sources
diet_mean = df_Obesity.describe().iloc[1]
diet_mean = pd.DataFrame(diet_mean).drop(['Deaths', 'Population','Undernourished','Obesity', 'Recovered', 'Confirmed', 'Active'], axis=0)
diet_mean = diet_mean.sort_values(by='mean', ascending=False).iloc[:11]
diet_mean.plot.pie(subplots=True, figsize=(20, 20), autopct='%1.1f%%')
# Out:
# array([<AxesSubplot:ylabel='mean'>], dtype=object)

# %% [markdown]
# Undernourished people consume much less animal products, and consume much more starchy roots than the world's consumption in average. Moreover, undernourished seem to be consuming a bit more alcoholic beverages.

# %%
# Obesity average Diet
obesity_set = df_Obesity[df_Obesity['Obesity'] == df_Obesity['Obesity']].sort_values(by='Obesity', ascending=False).head(10)
obesity_mean = obesity_set.describe().iloc[1]
obesity_mean = pd.DataFrame(obesity_mean).drop(['Deaths', 'Population','Undernourished','Obesity', 'Recovered', 'Confirmed', 'Active'], axis=0)
obesity_mean = obesity_mean.sort_values(by='mean', ascending=False).iloc[:11]


obesity_mean.plot.pie(subplots=True, figsize=(25, 25), autopct='%1.1f%%')

obesity_mean.plot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(40, 7))
plt.subplot(1,2,1)
plt.scatter(df_Obesity["Obesity"],df_Obesity["Confirmed"],label="Confirmed")
plt.scatter(df_Obesity["Obesity"],df_Obesity["Recovered"], label="Recovered")
plt.scatter(df_Obesity["Obesity"],df_Obesity["Deaths"], label="Deaths")

plt.title('Obesity Vs Covid19')
plt.xlabel('Percentage of Obesity')
plt.ylabel('Covid19')
plt.legend(loc='best')

# %%
#We can see the correlation between obesity and spread of COVID-19 from the visualizations

# %% [markdown]
# Distribution of food intake (in kg) - exploring high obesity cases
# Let's inspect this further. What can we say about the food intake in countries grouped by obesity rate?

# %%
df_high_ob = fat_supply_quantity[fat_supply_quantity.Obesity > fat_supply_quantity['Obesity'].mean()]
df_low_ob = fat_supply_quantity[fat_supply_quantity.Obesity <= fat_supply_quantity['Obesity'].mean()]

# %%
fat_supply_quantity['ObesityAboveAvg'] = (fat_supply_quantity["Obesity"] > fat_supply_quantity['Obesity'].mean()).astype(int)

# %% [markdown]
# We have created a column ObesityAboveAvg that has value 1 if the country has obesity rate above the mean of all other countries, and 0 otherwise.

# %%
fat_supply_quantity
# Out:
#                           Alcoholic Beverages  Animal Products  Animal fats  \
# Country
# Samoa                                     0.0          21.6806       4.7780
# United States of America                  0.0          21.2045       3.3013
# Kuwait                                    0.0          19.8923       2.1588
# Saudi Arabia                              0.0          15.3954       2.6475
# Jordan                                    0.0          12.2622       1.8696
# ...                                       ...              ...          ...
# Ethiopia                                  0.0          11.1691       1.4358
# Cambodia                                  0.0          18.8510       0.8839
# Bangladesh                                0.0           9.8365       1.2369
# Timor-Leste                               0.0          17.8988       2.0345
# Vietnam                                   0.0          33.2484       3.8238
#
#                           Aquatic Products, Other  Cereals - Excluding Beer  \
# Country
# Samoa                                      0.0036                    1.5771
# United States of America                   0.0000                    1.2829
# Kuwait                                     0.0000                    3.0847
# Saudi Arabia                               0.0000                    5.2126
# Jordan                                     0.0000                    3.7391
# ...                                           ...                       ...
# Ethiopia                                   0.0000                   11.3929
# Cambodia                                   0.0000                    9.4179
# Bangladesh                                 0.0000                    6.9946
# Timor-Leste                                0.0000                   10.2168
# Vietnam                                    0.0000                    3.7155
#
#                             Eggs  Fish, Seafood  Fruits - Excluding Wine  \
# Country
# Samoa                     0.2227         1.8968                   0.6287
# United States of America  1.2500         0.3887                   0.4426
# Kuwait                    2.3242         0.3732                   0.3496
# Saudi Arabia              0.9019         0.4122                   0.4219
# Jordan                    0.5224         0.3189                   0.1980
# ...                          ...            ...                      ...
# Ethiopia                  0.2238         0.0559                   0.4102
# Cambodia                  0.5639         4.8461                   0.2438
# Bangladesh                1.2664         2.1646                   0.4270
# Timor-Leste               0.2446         0.7893                   1.3007
# Vietnam                   0.7839         1.1217                   0.4079
#
#                              Meat  Miscellaneous  ...  Vegetable Oils  \
# Country                                           ...
# Samoa                     13.2418         0.0683  ...          8.3345
# United States of America   9.4166         0.0000  ...         23.6117
# Kuwait                     9.5706         0.1086  ...         21.2150
# Saudi Arabia               6.9243         0.0873  ...         25.4182
# Jordan                     5.8122         0.0385  ...         29.0553
# ...                           ...            ...  ...             ...
# Ethiopia                   4.1768         0.0000  ...         17.4156
# Cambodia                  11.7799         0.1372  ...         11.2313
# Bangladesh                 1.8407         0.0147  ...         29.6422
# Timor-Leste               14.5525         0.1112  ...         15.9644
# Vietnam                   26.4292         0.0064  ...          5.6211
#
#                           Vegetables  Obesity  Undernourished  Confirmed  \
# Country
# Samoa                         0.0431     45.5             2.7   0.001000
# United States of America      0.1944     37.3             2.5   8.159922
# Kuwait                        0.5055     37.0             2.8   3.624728
# Saudi Arabia                  0.1891     35.0             7.1   1.055795
# Jordan                        0.2694     33.4            12.2   3.126276
# ...                              ...      ...             ...        ...
# Ethiopia                      0.1305      3.6            20.6   0.123093
# Cambodia                      0.2591      3.5            16.4   0.003059
# Bangladesh                    0.3092      3.4            14.7   0.316691
# Timor-Leste                   0.1668      2.9            24.9   0.006070
# Vietnam                       0.6373      2.1             9.3   0.002063
#
#                             Deaths  Recovered    Active   Population  \
# Country
# Samoa                     0.000000   0.001000  0.000000     200000.0
# United States of America  0.140103   0.000000  8.019819  329878000.0
# Kuwait                    0.020550   3.434087  0.170092    4691000.0
# Saudi Arabia              0.018256   1.030898  0.006641   35041000.0
# Jordan                    0.040912   2.991760  0.093604   10679000.0
# ...                            ...        ...       ...          ...
# Ethiopia                  0.001867   0.109237  0.011989  114916000.0
# Cambodia                  0.000000   0.002930  0.000129   15497000.0
# Bangladesh                0.004823   0.284344  0.027524  169809000.0
# Timor-Leste               0.000000   0.004628  0.001442    1318000.0
# Vietnam                   0.000036   0.001526  0.000501   96209000.0
#
#                           ObesityAboveAvg
# Country
# Samoa                                   1
# United States of America                1
# Kuwait                                  1
# Saudi Arabia                            1
# Jordan                                  1
# ...                                   ...
# Ethiopia                                0
# Cambodia                                0
# Bangladesh                              0
# Timor-Leste                             0
# Vietnam                                 0
#
# [154 rows x 31 columns]

# %%
#@title Get correlation matrix

df_Obesity.corr()
# Out:
#                           Alcoholic Beverages  Animal Products  Animal fats  \
# Alcoholic Beverages                  1.000000        -0.070871    -0.036746
# Animal Products                     -0.070871         1.000000     0.697547
# Animal fats                         -0.036746         0.697547     1.000000
# Aquatic Products, Other              0.751088         0.019938     0.000170
# Cereals - Excluding Beer             0.103028        -0.450856    -0.399728
# Eggs                                 0.014224         0.469609     0.272433
# Fish, Seafood                        0.084251        -0.028597    -0.106917
# Fruits - Excluding Wine             -0.050626        -0.122182    -0.168040
# Meat                                -0.017627         0.727150     0.228829
# Miscellaneous                       -0.071114         0.118110    -0.071821
# Milk - Excluding Butter             -0.134626         0.630605     0.340023
# Offals                               0.012041         0.071864    -0.177587
# Oilcrops                             0.056684        -0.432341    -0.340746
# Pulses                              -0.067931        -0.429942    -0.317477
# Spices                              -0.049383        -0.191237    -0.201837
# Starchy Roots                       -0.040578        -0.395685    -0.319877
# Stimulants                          -0.076078         0.471674     0.276179
# Sugar Crops                         -0.022015        -0.034550    -0.026015
# Sugar & Sweeteners                  -0.019659        -0.078871    -0.076881
# Treenuts                            -0.007365         0.156046     0.147070
# Vegetal Products                     0.070872        -1.000000    -0.697541
# Vegetable Oils                       0.019107        -0.680423    -0.383968
# Vegetables                           0.082013         0.106243    -0.056598
# Obesity                             -0.154252         0.449033     0.410688
# Undernourished                       0.105441        -0.488053    -0.395764
# Confirmed                           -0.087095         0.498583     0.511528
# Deaths                              -0.084189         0.453201     0.517192
# Recovered                           -0.073849         0.411739     0.452143
# Active                              -0.044496         0.271567     0.234097
# Population                          -0.007711         0.010433     0.017760
#
#                           Aquatic Products, Other  Cereals - Excluding Beer  \
# Alcoholic Beverages                      0.751088                  0.103028
# Animal Products                          0.019938                 -0.450856
# Animal fats                              0.000170                 -0.399728
# Aquatic Products, Other                  1.000000                 -0.091117
# Cereals - Excluding Beer                -0.091117                  1.000000
# Eggs                                     0.092510                 -0.304144
# Fish, Seafood                            0.128302                 -0.025438
# Fruits - Excluding Wine                 -0.042575                  0.030985
# Meat                                     0.083026                 -0.255698
# Miscellaneous                           -0.030819                 -0.011784
# Milk - Excluding Butter                 -0.117022                 -0.276512
# Offals                                   0.034194                  0.277489
# Oilcrops                                -0.012271                  0.155615
# Pulses                                  -0.076131                  0.408321
# Spices                                  -0.030897                  0.147511
# Starchy Roots                           -0.054604                  0.204101
# Stimulants                              -0.042358                 -0.295385
# Sugar Crops                             -0.020559                  0.201196
# Sugar & Sweeteners                       0.024582                  0.007171
# Treenuts                                 0.051227                 -0.207931
# Vegetal Products                        -0.019900                  0.450855
# Vegetable Oils                           0.035041                 -0.037461
# Vegetables                               0.161518                 -0.030121
# Obesity                                 -0.121690                 -0.484577
# Undernourished                          -0.076027                  0.482489
# Confirmed                               -0.092494                 -0.439677
# Deaths                                  -0.087285                 -0.395413
# Recovered                               -0.079432                 -0.328107
# Active                                  -0.045890                 -0.289829
# Population                               0.125152                 -0.011456
#
#                               Eggs  Fish, Seafood  Fruits - Excluding Wine  \
# Alcoholic Beverages       0.014224       0.084251                -0.050626
# Animal Products           0.469609      -0.028597                -0.122182
# Animal fats               0.272433      -0.106917                -0.168040
# Aquatic Products, Other   0.092510       0.128302                -0.042575
# Cereals - Excluding Beer -0.304144      -0.025438                 0.030985
# Eggs                      1.000000       0.231742                -0.079029
# Fish, Seafood             0.231742       1.000000                 0.019655
# Fruits - Excluding Wine  -0.079029       0.019655                 1.000000
# Meat                      0.247868      -0.019544                -0.041831
# Miscellaneous             0.070388       0.461753                -0.029662
# Milk - Excluding Butter   0.260279      -0.251349                -0.060000
# Offals                   -0.129690      -0.086731                 0.079822
# Oilcrops                 -0.345849       0.299748                 0.067529
# Pulses                   -0.334296      -0.103988                 0.505992
# Spices                   -0.022421       0.219261                -0.013361
# Starchy Roots            -0.358308       0.181851                 0.453843
# Stimulants                0.255856       0.026865                -0.091881
# Sugar Crops              -0.102687       0.104026                 0.009270
# Sugar & Sweeteners        0.071198       0.143526                 0.041623
# Treenuts                  0.289976       0.175843                -0.087501
# Vegetal Products         -0.469665       0.028547                 0.122013
# Vegetable Oils           -0.201963      -0.201150                -0.073094
# Vegetables                0.170721       0.042205                 0.043523
# Obesity                   0.319066      -0.215471                -0.090983
# Undernourished           -0.464595      -0.063977                 0.187930
# Confirmed                 0.340620      -0.146445                -0.080842
# Deaths                    0.312120      -0.216102                -0.089725
# Recovered                 0.305001      -0.130530                -0.060444
# Active                    0.151422      -0.062995                -0.052507
# Population                0.143642      -0.005814                -0.040913
#
#                               Meat  Miscellaneous  ...  Vegetal Products  \
# Alcoholic Beverages      -0.017627      -0.071114  ...          0.070872
# Animal Products           0.727150       0.118110  ...         -1.000000
# Animal fats               0.228829      -0.071821  ...         -0.697541
# Aquatic Products, Other   0.083026      -0.030819  ...         -0.019900
# Cereals - Excluding Beer -0.255698      -0.011784  ...          0.450855
# Eggs                      0.247868       0.070388  ...         -0.469665
# Fish, Seafood            -0.019544       0.461753  ...          0.028547
# Fruits - Excluding Wine  -0.041831      -0.029662  ...          0.122013
# Meat                      1.000000       0.137311  ...         -0.727139
# Miscellaneous             0.137311       1.000000  ...         -0.118143
# Milk - Excluding Butter   0.127680       0.033038  ...         -0.630601
# Offals                    0.260314      -0.095124  ...         -0.071852
# Oilcrops                 -0.230770      -0.034559  ...          0.432322
# Pulses                   -0.331804      -0.087838  ...          0.429813
# Spices                   -0.164765       0.158135  ...          0.191146
# Starchy Roots            -0.158022      -0.065571  ...          0.395583
# Stimulants                0.258685       0.300133  ...         -0.471657
# Sugar Crops               0.023006      -0.021457  ...          0.034632
# Sugar & Sweeteners       -0.005679      -0.053986  ...          0.078937
# Treenuts                 -0.035107       0.126541  ...         -0.156038
# Vegetal Products         -0.727139      -0.118143  ...          1.000000
# Vegetable Oils           -0.565979      -0.165788  ...          0.680472
# Vegetables                0.042828      -0.012494  ...         -0.106183
# Obesity                   0.243416       0.027524  ...         -0.449021
# Undernourished           -0.230810      -0.052968  ...          0.488053
# Confirmed                 0.183814      -0.059373  ...         -0.498624
# Deaths                    0.172689      -0.174682  ...         -0.453236
# Recovered                 0.134809      -0.003424  ...         -0.411771
# Active                    0.124287      -0.093392  ...         -0.271593
# Population                0.025764      -0.053906  ...         -0.010433
#
#                           Vegetable Oils  Vegetables   Obesity  \
# Alcoholic Beverages             0.019107    0.082013 -0.154252
# Animal Products                -0.680423    0.106243  0.449033
# Animal fats                    -0.383968   -0.056598  0.410688
# Aquatic Products, Other         0.035041    0.161518 -0.121690
# Cereals - Excluding Beer       -0.037461   -0.030121 -0.484577
# Eggs                           -0.201963    0.170721  0.319066
# Fish, Seafood                  -0.201150    0.042205 -0.215471
# Fruits - Excluding Wine        -0.073094    0.043523 -0.090983
# Meat                           -0.565979    0.042828  0.243416
# Miscellaneous                  -0.165788   -0.012494  0.027524
# Milk - Excluding Butter        -0.381919    0.202277  0.340042
# Offals                         -0.230953    0.078222 -0.259794
# Oilcrops                       -0.197788   -0.107569 -0.278508
# Pulses                          0.079153   -0.037857 -0.399282
# Spices                         -0.048650    0.218041 -0.234701
# Starchy Roots                   0.054085   -0.080137 -0.352706
# Stimulants                     -0.334033    0.143510  0.353145
# Sugar Crops                    -0.061801    0.291322 -0.213924
# Sugar & Sweeteners              0.031277   -0.029060 -0.127617
# Treenuts                       -0.058953    0.292373  0.195611
# Vegetal Products                0.680472   -0.106183 -0.449021
# Vegetable Oils                  1.000000   -0.137096 -0.107572
# Vegetables                     -0.137096    1.000000 -0.031311
# Obesity                        -0.107572   -0.031311  1.000000
# Undernourished                  0.243612   -0.232486 -0.572341
# Confirmed                      -0.154324   -0.003671  0.525496
# Deaths                         -0.102064   -0.003479  0.488841
# Recovered                      -0.155732    0.052836  0.419179
# Active                         -0.044860   -0.082142  0.307033
# Population                      0.014203    0.090792 -0.180921
#
#                           Undernourished  Confirmed    Deaths  Recovered  \
# Alcoholic Beverages             0.105441  -0.087095 -0.084189  -0.073849
# Animal Products                -0.488053   0.498583  0.453201   0.411739
# Animal fats                    -0.395764   0.511528  0.517192   0.452143
# Aquatic Products, Other        -0.076027  -0.092494 -0.087285  -0.079432
# Cereals - Excluding Beer        0.482489  -0.439677 -0.395413  -0.328107
# Eggs                           -0.464595   0.340620  0.312120   0.305001
# Fish, Seafood                  -0.063977  -0.146445 -0.216102  -0.130530
# Fruits - Excluding Wine         0.187930  -0.080842 -0.089725  -0.060444
# Meat                           -0.230810   0.183814  0.172689   0.134809
# Miscellaneous                  -0.052968  -0.059373 -0.174682  -0.003424
# Milk - Excluding Butter        -0.359135   0.411789  0.336616   0.329557
# Offals                          0.282721  -0.248037 -0.194233  -0.163697
# Oilcrops                        0.175632  -0.376036 -0.365486  -0.319305
# Pulses                          0.396053  -0.321033 -0.309363  -0.248784
# Spices                         -0.051351  -0.175790 -0.159488  -0.116351
# Starchy Roots                   0.384649  -0.331759 -0.292750  -0.275574
# Stimulants                     -0.334674   0.483254  0.314030   0.521487
# Sugar Crops                     0.028917  -0.123934 -0.121137  -0.096602
# Sugar & Sweeteners              0.040325  -0.081139 -0.073025  -0.059829
# Treenuts                       -0.274380   0.238959  0.153007   0.186904
# Vegetal Products                0.488053  -0.498624 -0.453236  -0.411771
# Vegetable Oils                  0.243612  -0.154324 -0.102064  -0.155732
# Vegetables                     -0.232486  -0.003671 -0.003479   0.052836
# Obesity                        -0.572341   0.525496  0.488841   0.419179
# Undernourished                  1.000000  -0.458968 -0.429664  -0.375703
# Confirmed                      -0.458968   1.000000  0.857164   0.815635
# Deaths                         -0.429664   0.857164  1.000000   0.658868
# Recovered                      -0.375703   0.815635  0.658868   1.000000
# Active                         -0.254305   0.561168  0.529162  -0.021054
# Population                     -0.012175  -0.081559 -0.055888  -0.105708
#
#                             Active  Population
# Alcoholic Beverages      -0.044496   -0.007711
# Animal Products           0.271567    0.010433
# Animal fats               0.234097    0.017760
# Aquatic Products, Other  -0.045890    0.125152
# Cereals - Excluding Beer -0.289829   -0.011456
# Eggs                      0.151422    0.143642
# Fish, Seafood            -0.062995   -0.005814
# Fruits - Excluding Wine  -0.052507   -0.040913
# Meat                      0.124287    0.025764
# Miscellaneous            -0.093392   -0.053906
# Milk - Excluding Butter   0.240731   -0.055770
# Offals                   -0.195248    0.081059
# Oilcrops                 -0.191383   -0.031121
# Pulses                   -0.197653    0.100499
# Spices                   -0.137105    0.050642
# Starchy Roots            -0.178724   -0.044754
# Stimulants                0.092153   -0.106198
# Sugar Crops              -0.075439    0.017707
# Sugar & Sweeteners       -0.054517    0.266159
# Treenuts                  0.147450    0.052015
# Vegetal Products         -0.271593   -0.010433
# Vegetable Oils           -0.044860    0.014203
# Vegetables               -0.082142    0.090792
# Obesity                   0.307033   -0.180921
# Undernourished           -0.254305   -0.012175
# Confirmed                 0.561168   -0.081559
# Deaths                    0.529162   -0.055888
# Recovered                -0.021054   -0.105708
# Active                    1.000000    0.009940
# Population                0.009940    1.000000
#
# [30 rows x 30 columns]

# %% [markdown]
# # Modeling: Building a Linear Regression Model in sklearn

# %% [markdown]
# The sections bellow are dedicted to the processes of creating, training and evaluating the model.

# %% [markdown]
# scikit-learn's Four-Step Modeling Pattern
#
# Step 1: Import the class you plan to use.
#
# Step 2: "Instantiate" the "estimator."
#
# Step 3: Fit the model with data (aka "model training").
#
# Step 4: Predict the response for a new observation.

# %%
#import packages
import statsmodels.api as sm
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
plt.style.use("fivethirtyeight")

# %% [markdown]
# # Selecting Features for a Linear Regression Model
#
# Feature and Target Selection

# %% [markdown]
# Let's compare these metrics:
#
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world. Also, MSE is continuous and differentiable, making it easier to use than MAE for optimization.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.
# All of these are loss functions, because we want to minimize them.
#
# Here's an additional example, to demonstrate how MSE/RMSE punishes larger errors:

# %%
# Calculate these metrics by hand!
from sklearn import metrics
import numpy as np
print('MAE:', metrics.mean_absolute_error(true, pred))
print('MSE:', metrics.mean_squared_error(true, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(true, pred))
# Out:
#   File "<ipython-input-107-4890216db0f2>", line 6
#     print('RMSE:', np.sqrt(metrics.mean_squared_error(true, pred))
#                                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
# Same true values as above
true = [10, 7, 5, 5]

# New set of predicted values
pred = [10, 7, 5, 13]

# MAE is the same as before.
print('MAE:', metrics.mean_absolute_error(true, pred))

# MSE and RMSE are larger than before.
print('MSE:', metrics.mean_squared_error(true, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(true, pred)))
# Out:
# MAE: 2.0
# MSE: 16.0
# RMSE: 4.0

# %%
from sklearn.model_selection import train_test_split

# Define a function that accepts a list of features and returns testing RMSE.
def train_test_rmse(df, feature_cols, response):
    X = df[feature_cols]
    y = df[response]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123)
    
    linreg = LinearRegression()
    linreg.fit(X_train, y_train)
    
    y_pred = linreg.predict(X_test)
    return np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
# Define features and labels.
feature_names = ['animal_products', 'cereals_excluding_beer', 'obesity', 'vegetal_products']
label_name = 'deaths'

# %%
data = fat_supply_quantity.drop('Population', axis=1)

data = fat_supply_quantity.drop(['Confirmed', 'Recovered', 'Active'], axis=1)
pd.qcut(data['Deaths'], q=2, labels=[0, 1]).value_counts()
# Out:
# 1    77
# 0    77
# Name: Deaths, dtype: int64

# %%
data['Deaths'] = pd.qcut(data['Deaths'], q=2, labels=[0, 1])

# %% [markdown]
# Splitting & Scaling the dataset
#
# We split the dataset into training and testing data, separating the features from the label.

# %%
data
# Out:
#                           Alcoholic Beverages  Animal Products  Animal fats  \
# Country
# Samoa                                     0.0          21.6806       4.7780
# United States of America                  0.0          21.2045       3.3013
# Kuwait                                    0.0          19.8923       2.1588
# Saudi Arabia                              0.0          15.3954       2.6475
# Jordan                                    0.0          12.2622       1.8696
# ...                                       ...              ...          ...
# Ethiopia                                  0.0          11.1691       1.4358
# Cambodia                                  0.0          18.8510       0.8839
# Bangladesh                                0.0           9.8365       1.2369
# Timor-Leste                               0.0          17.8988       2.0345
# Vietnam                                   0.0          33.2484       3.8238
#
#                           Aquatic Products, Other  Cereals - Excluding Beer  \
# Country
# Samoa                                      0.0036                    1.5771
# United States of America                   0.0000                    1.2829
# Kuwait                                     0.0000                    3.0847
# Saudi Arabia                               0.0000                    5.2126
# Jordan                                     0.0000                    3.7391
# ...                                           ...                       ...
# Ethiopia                                   0.0000                   11.3929
# Cambodia                                   0.0000                    9.4179
# Bangladesh                                 0.0000                    6.9946
# Timor-Leste                                0.0000                   10.2168
# Vietnam                                    0.0000                    3.7155
#
#                             Eggs  Fish, Seafood  Fruits - Excluding Wine  \
# Country
# Samoa                     0.2227         1.8968                   0.6287
# United States of America  1.2500         0.3887                   0.4426
# Kuwait                    2.3242         0.3732                   0.3496
# Saudi Arabia              0.9019         0.4122                   0.4219
# Jordan                    0.5224         0.3189                   0.1980
# ...                          ...            ...                      ...
# Ethiopia                  0.2238         0.0559                   0.4102
# Cambodia                  0.5639         4.8461                   0.2438
# Bangladesh                1.2664         2.1646                   0.4270
# Timor-Leste               0.2446         0.7893                   1.3007
# Vietnam                   0.7839         1.1217                   0.4079
#
#                              Meat  Miscellaneous  ...  Sugar Crops  \
# Country                                           ...
# Samoa                     13.2418         0.0683  ...       0.0000
# United States of America   9.4166         0.0000  ...       0.0000
# Kuwait                     9.5706         0.1086  ...       0.0000
# Saudi Arabia               6.9243         0.0873  ...       0.0000
# Jordan                     5.8122         0.0385  ...       0.0000
# ...                           ...            ...  ...          ...
# Ethiopia                   4.1768         0.0000  ...       0.0000
# Cambodia                  11.7799         0.1372  ...       0.0762
# Bangladesh                 1.8407         0.0147  ...       0.0147
# Timor-Leste               14.5525         0.1112  ...       0.0000
# Vietnam                   26.4292         0.0064  ...       0.0382
#
#                           Sugar & Sweeteners  Treenuts  Vegetal Products  \
# Country
# Samoa                                    0.0    0.0611           28.3194
# United States of America                 0.0    0.9420           28.7970
# Kuwait                                   0.0    1.1810           30.1101
# Saudi Arabia                             0.0    0.7128           34.6070
# Jordan                                   0.0    0.9018           37.7378
# ...                                      ...       ...               ...
# Ethiopia                                 0.0    0.7459           38.8216
# Cambodia                                 0.0    0.3048           31.1490
# Bangladesh                               0.0    0.2651           40.1561
# Timor-Leste                              0.0    0.0111           32.1067
# Vietnam                                  0.0    1.1726           16.7548
#
#                           Vegetable Oils  Vegetables  Obesity  Undernourished  \
# Country
# Samoa                             8.3345      0.0431     45.5             2.7
# United States of America         23.6117      0.1944     37.3             2.5
# Kuwait                           21.2150      0.5055     37.0             2.8
# Saudi Arabia                     25.4182      0.1891     35.0             7.1
# Jordan                           29.0553      0.2694     33.4            12.2
# ...                                  ...         ...      ...             ...
# Ethiopia                         17.4156      0.1305      3.6            20.6
# Cambodia                         11.2313      0.2591      3.5            16.4
# Bangladesh                       29.6422      0.3092      3.4            14.7
# Timor-Leste                      15.9644      0.1668      2.9            24.9
# Vietnam                           5.6211      0.6373      2.1             9.3
#
#                           Deaths   Population
# Country
# Samoa                          0     200000.0
# United States of America       1  329878000.0
# Kuwait                         1    4691000.0
# Saudi Arabia                   1   35041000.0
# Jordan                         1   10679000.0
# ...                          ...          ...
# Ethiopia                       0  114916000.0
# Cambodia                       0   15497000.0
# Bangladesh                     0  169809000.0
# Timor-Leste                    0    1318000.0
# Vietnam                        0   96209000.0
#
# [154 rows x 27 columns]

# %%
#create X and Y
y = data['Deaths']
X = data.drop('Deaths', axis=1)

# %%
# Check X's type.
print((type(X)))
print((type(X.values)))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %%
# Check y's type.
print((type(y)))
print((type(y.values)))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.arrays.categorical.Categorical'>

# %% [markdown]
# Training the Dataset

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(food_kg, test_size=0.2)

# %%
y = fat_supply_quantity['Deaths']
X = fat_supply_quantity.drop('Deaths', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
X.shape
# Out:
# (154, 29)

# %%
test_set.head()
# Out:
#              Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 139  Solomon Islands               0.8298       0.1038           3.8504
# 30             China               2.3224       0.0866          13.4240
# 119         Paraguay               3.9095       0.2191          11.2654
# 29             Chile               4.9690       0.1782          15.0394
# 144         Suriname               4.1704       0.0438           6.7984
#
#      Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 139                   0.0121                    9.0233  0.0826         2.2840
# 30                    0.0542                    8.9298  1.2059         3.3435
# 119                   0.0000                    7.5639  0.9035         0.3119
# 29                    0.0155                   10.8579  0.7757         0.8711
# 144                   0.0000                   13.9476  0.5407         1.4348
#
#      Fruits - Excluding Wine    Meat  ...  Vegetables  Vegetal Products  \
# 139                   3.2798  0.8897  ...      1.1223           46.1492
# 30                    4.2451  6.0732  ...     13.0990           36.5744
# 119                   5.4532  4.0434  ...      3.7113           38.7260
# 29                    3.9109  6.1492  ...      5.3092           34.9584
# 144                   8.6872  3.6451  ...      5.3705           43.1917
#
#      Obesity  Undernourished  Confirmed    Deaths  Recovered    Active  \
# 139     20.5             8.9   0.002378  0.000000   0.001399  0.000979
# 30       6.6             8.5   0.006961  0.000342   0.006496  0.000123
# 119     19.0            10.7   1.664907  0.034170   1.320675  0.310062
# 29      28.8             2.7   3.395891  0.089209   3.170889       NaN
# 144     26.5             8.5   1.224628  0.022975   1.094380  0.107273
#
#        Population  Unit (all except Population)
# 139  7.150000e+05                             %
# 30   1.402385e+09                             %
# 119  7.255000e+06                             %
# 29   1.947000e+07                             %
# 144  6.050000e+05                             %
#
# [5 rows x 32 columns]

# %% [markdown]
# The test and train sets seem representative.
#
# I dropped the labels from the training set and created a new variable for the labels.

# %%
food_kg_train = train_set.drop("Deaths", axis=1) # drop labels for training set
food_kg_train_labels = train_set["Deaths"].copy()

food_kg_test = test_set.drop("Deaths", axis=1) # drop labels for test set
food_kg_test_labels = test_set["Deaths"].copy()

# %% [markdown]
# Here, we don't need an imputer or any additional manipulations since we no longer have any missing values.

# %%
food_kg_train_num = food_kg_train.drop('Country', axis=1)
food_kg_test_num = food_kg_test.drop('Country', axis=1)

# %% [markdown]
# Performing feature scaling ¶
#
# Performing features scaling on the cleaned training and testing food_kg datasets.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
food_kg_train_coun = food_kg_train[['Country']]
food_kg_test_coun = food_kg_test[['Country']]
food_kg_test_coun.tail(3)
# Out:
#          Country
# 56       Germany
# 150  Timor-Leste
# 111    Nicaragua

# %% [markdown]
# schikit-learn's 4 step modeling pattern
#
# Step 1: Import the class you plan to use.
#
# Step 2: "Instantiate" the "estimator."
#
# Step 3: Fit the model with data (aka "model training").
#
# Step 4: Predict the response for a new observation.

# %%
from sklearn.linear_model import LinearRegression

# %%
# Make an instance of a LinearRegression object.
lr = LinearRegression()
type(lr)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
# help(lr)
lr
# Out:
# LinearRegression()

# %%
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
# Print the coefficients.
print(lr.intercept_)
print(lr.coef_)
# Out:
# 9.723256921834178e-11
# [ 4.60173558e-11 -5.60448702e-13 -1.43101799e-12 -4.16495037e-12
#   6.15382748e-13  1.06214357e-12 -5.61887043e-12 -2.90583345e-12
#  -9.12027705e-13  1.62982701e-12 -6.31641170e-13  1.22631009e-12
#   9.92964413e-13  4.73639022e-12 -3.77081375e-12  4.22524547e-12
#  -4.27972880e-12 -3.93927254e-13 -1.10466841e-12  1.18654659e-12
#  -2.33348052e-12  5.62745016e-13 -1.55541557e-11 -1.94485742e-13
#  -2.22566311e-13  1.00000000e+00 -1.00000000e+00 -1.00000000e+00
#  -2.88686034e-21]

# %%
dict(zip(lr.coef_,X.columns))
# Out:
# {4.601735580800011e-11: 'Alcoholic Beverages',
#  -5.604487023058045e-13: 'Animal Products',
#  -1.4310179934034918e-12: 'Animal fats',
#  -4.164950370419734e-12: 'Aquatic Products, Other',
#  6.153827477752567e-13: 'Cereals - Excluding Beer',
#  1.0621435654192591e-12: 'Eggs',
#  -5.618870434335872e-12: 'Fish, Seafood',
#  -2.905833445912101e-12: 'Fruits - Excluding Wine',
#  -9.120277045506105e-13: 'Meat',
#  1.6298270127229933e-12: 'Miscellaneous',
#  -6.316411696090454e-13: 'Milk - Excluding Butter',
#  1.2263100899359945e-12: 'Offals',
#  9.92964413267528e-13: 'Oilcrops',
#  4.736390215719358e-12: 'Pulses',
#  -3.770813753769839e-12: 'Spices',
#  4.22524547459918e-12: 'Starchy Roots',
#  -4.279728803511023e-12: 'Stimulants',
#  -3.9392725417042654e-13: 'Sugar Crops',
#  -1.1046684106257799e-12: 'Sugar & Sweeteners',
#  1.1865465938280107e-12: 'Treenuts',
#  -2.3334805228619786e-12: 'Vegetal Products',
#  5.627450158978472e-13: 'Vegetable Oils',
#  -1.555415569355808e-11: 'Vegetables',
#  -1.94485741623828e-13: 'Obesity',
#  -2.2256631056398791e-13: 'Undernourished',
#  1.0000000000001052: 'Confirmed',
#  -0.9999999999991569: 'Recovered',
#  -1.0000000000011362: 'Active',
#  -2.8868603378100666e-21: 'Population'}

# %%
# Use the predict method.
linreg.predict([[]]
# Out:
#   File "<ipython-input-104-11b702134260>", line 2
#     linreg.predict([[0]]
#                         ^
# SyntaxError: unexpected EOF while parsing

# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.15.3-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: nltk>=3.1 in /Users/perrisolhjou/opt/anaconda3/lib/python3.8/site-packages (from textblob) (3.5)
# Requirement already satisfied: regex in /Users/perrisolhjou/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (2020.10.15)
# Requirement already satisfied: joblib in /Users/perrisolhjou/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (0.17.0)
# Requirement already satisfied: click in /Users/perrisolhjou/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: tqdm in /Users/perrisolhjou/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (4.50.2)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer

# %% [markdown]
# # DO I INCLUDE THIS ??
#
# # Compare different sets of features.
# print(train_test_rmse(bikes, ['temp', 'season', 'weather', 'humidity'], 'total_rentals'))
# print(train_test_rmse(bikes, ['temp', 'season', 'weather'],'total_rentals'))
# print(train_test_rmse(bikes, ['temp', 'season', 'humidity'],'total_rentals'))

# %% [markdown]
# INCLUDE HYPERPARAMETER TUNING
